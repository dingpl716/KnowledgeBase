# %% [markdown]
# ### Parameters:
# - days = 14
# - p = 1
# - i = 1
# - d = 1
# - f = 1
# - target_impression = 30000
# - setpoint = target_impression / (days * 24 * 3600)
# - no max output limt

# %%
import pandas as pd

# %%
file_path = '../data/pid_3.1.csv'
df = pd.read_csv(file_path, parse_dates=['datetime'])
df = df.drop(0)
df.set_index('datetime', inplace=True)

# %%
df['current_velocity'].plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
df['desired_velocity'].plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='datetime'>
