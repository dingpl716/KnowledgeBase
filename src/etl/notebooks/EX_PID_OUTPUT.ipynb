# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/peiling/Projects/dingpl716/ex_pid/output.csv', parse_dates=['datetime'])

# %%
df.set_index('datetime', inplace=True)

# %%
# df['theoretical_velocity'].plot(figsize=(16,9))

# %%
df['actual_velocity'].plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
df['desired_velocity'].plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='datetime'>
