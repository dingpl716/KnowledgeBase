# %% [markdown]
# ### Parameters:
# - days = 14
# - target_impression = 30000
# - setpoint = target_impression / (days * 24 * 3600)
# - p = 1
# - i = 1
# - d = 1, but d is negtive in the controller `d_output = -state.kd * (input - state.last_input)`
# - f = 0
# - no max output limt

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/pid_1.csv')

# %%
start = df.loc[0, 'timestamp']
df = df.drop(0)
df['velocity'] = df['delivered_impression'] / (df['timestamp'] - start + 1)
df.set_index(pd.to_datetime(df['timestamp'], unit='s'), inplace=True)

# %%
df.head()
# Out:
#                      delivered_impression   timestamp  velocity
# timestamp
# 2022-04-01 02:10:57                     1  1648779057  0.043478
# 2022-04-01 02:11:19                     2  1648779079  0.044444
# 2022-04-01 02:11:41                     2  1648779101  0.029851
# 2022-04-01 02:12:03                     2  1648779123  0.022472
# 2022-04-01 02:12:26                     3  1648779146  0.026786

# %%
df_first = df.drop(df[df.index > '2022-04-01 03:00:00'].index)
df_first['velocity'].plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='timestamp'>
